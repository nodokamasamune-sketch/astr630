# %%
# math
'''
masses # given <-- solar units
lums  # given <-- solar units
teff # given <-- kelvins

temp #
radii # solve for
t_kh # solve for 
t_nuc # solve for
'''
# in solar units
t_kh_solar = ???
t_nuc_solar = ???
teff = 10**(teff)
radii = (lums**(1/2)) * ((teff / 5772)**(-2))
t_kh = (masses** 2) * (radii**(-1)) * (lums **(-1)) * t_kh_sol
t_nuc = (0.01/0.7) * masses * (lums**(-1)) * t_nuc_solar
